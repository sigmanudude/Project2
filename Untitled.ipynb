# %%
import os

import pandas as pd
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func, distinct # library to use aggregate functions
from sqlalchemy.sql import operators

# %%
file = "~/Desktop/homework/Project2/rawdata/trafficviolation.csv"

csv = pd.read_csv(file)
df = pd.DataFrame(csv)
df.head()
# Out:
#    Year  Qtr  Month                SubAgency  PoliceDistrictID ViolationType  \
# 0  2012    1      1  1st district, Rockville                 1      Citation
# 1  2012    1      1  1st district, Rockville                 1      Citation
# 2  2012    1      1  1st district, Rockville                 1      Citation
# 3  2012    1      1  1st district, Rockville                 1      Citation
# 4  2012    1      1  1st district, Rockville                 1      Citation
#
#   ViolationCategory VehicleGroup  PersonalInjury  PropertyDamage  Fatal  \
# 0       Distraction   Automobile               0               0      0
# 1       Distraction        Truck               0               0      0
# 2          Impaired   Automobile               1               0      0
# 3           Offense   Automobile               1               0      0
# 4           Offense    Motorcyle               0               0      0
#
#    ContributedToAccident  ViolationCount
# 0                      0               5
# 1                      0               1
# 2                      4              33
# 3                      1             140
# 4                      0               1

# %%
totals = [i+j+k for i,j,k in zip(df['greenBars'], df['orangeBars'], df['blueBars'])]
greenBars = [i / j * 100 for i,j in zip(df['greenBars'], totals)]
orangeBars = [i / j * 100 for i,j in zip(df['orangeBars'], totals)]
blueBars = [i / j * 100 for i,j in zip(df['blueBars'], totals)]
