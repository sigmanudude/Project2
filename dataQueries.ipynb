# %%
import os

import pandas as pd
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func, distinct # library to use aggregate functions
from sqlalchemy.sql import operators

# %%
# Declare global variables
dbPath = "trafficViolations/static/db"

dbName = "trafficViolations.sqlite"

# %%
# create the connection to SQLite db
eng = create_engine(f"sqlite:///{dbPath}/{dbName}")

# %%
# reflect an existing database into a new model
Base  = automap_base()

#prepare and reflect all tables wih data
Base.prepare(eng, reflect = True)

# %%
print(Base.classes.keys())
# Out:
# ['traffic_violations']

# %%
V = Base.classes['traffic_violations']

# %%
# create session
session = Session(bind = eng)

# %% [markdown]
# ### DATA Extraction Queries

# %%
# extract unique years
def getYears():
    res = pd.DataFrame(session.query(distinct(V.Year)).all(), columns = ['Year'])
    res['Year'] = res['Year'].astype(str)
    return res

getYears()
# Out:
#    Year
# 0  2012
# 1  2013
# 2  2014
# 3  2015
# 4  2016

# %%
# extract uniq Months
def getMonths():
    res = pd.DataFrame(session.query(distinct(V.Month)).all(), columns = ['Month'])
    return res

#getMonths()

# %%
# extract uniq Qtr
def getQtrs():
    res = pd.DataFrame(session.query(distinct(V.Qtr)).all(), columns = ['Qtr'])
    return res

#getQtrs()

# %%
# extract uniq SubAgency and Police District
def getPoliceDist():
    res = pd.DataFrame(session.query(V.SubAgency,V.PoliceDistrictID).distinct().all(), columns = ['SubAgency','PoliceDistrictID'])
    return res

# getPoliceDist()

# %%
# extract uniq ViolaitonCategory
def getVioCat():
    res = pd.DataFrame(session.query(distinct(V.ViolationCategory)).all(), columns = ['ViolationCategory'])
    return res

# getVioCat()

# %%
# extract uniq ViolationType
def getVioType():
    res = pd.DataFrame(session.query(distinct(V.ViolationType)).all(), columns = ['ViolationType'])
    return res

# getVioType()

# %%
# extract uniq Vehicle Grp
def getVehGrp():
    res = pd.DataFrame(session.query(distinct(V.VehicleGroup)).all(), columns = ['VehicleGroup'])
    return res

# getVehGrp()

# %%
def summarize_YR_QTR():
    res = pd.DataFrame(session.query(V.Year, V.Qtr, func.sum(V.ViolationCount)).\
            group_by(V.Qtr).group_by(V.Year).all(), columns = ['Year', 'Qtr','Total_ViolationCount'])
    return res

# summarize_YR_QTR()

# %%
# extract violation count by year and qtr
def violation_YOY_Change():
    df = summarize_YR_QTR()
    df_yoy = pd.pivot_table(df, values = "Total_ViolationCount", index = ['Year'], columns = ["Qtr"], aggfunc = np.sum)
    #caclculate year on year change
    df_yoy = df_yoy.pct_change()
    # drop na
    df_yoy = df_yoy.dropna(how = "any")    
    
    # reshape to normal dataframe strcuture
    df_yoy = pd.DataFrame(df_yoy.unstack())
    df_yoy.rename(columns = {0: 'YOY_Change_PCT'}, inplace = True)
    df_yoy.reset_index(inplace = True)
    
    #
    
    #merge total violations and yoy df for final df
    df_final = pd.merge(df, df_yoy, on = ['Year','Qtr'])
    
    #convert YOY to % and round off to two digits
    df_final.YOY_Change_PCT = (df_final.YOY_Change_PCT * 100).apply(round, 2)
    
    
    return df_final
    
#     
# violation_YOY_Change()
# Out:
#     Year  Qtr  Total_ViolationCount  YOY_Change_PCT
# 0   2013    1                 29480              27
# 1   2014    1                 34673              18
# 2   2015    1                 36555               5
# 3   2016    1                 39279               7
# 4   2013    2                 32007              12
# 5   2014    2                 40661              27
# 6   2015    2                 41111               1
# 7   2016    2                 40576              -1
# 8   2013    3                 35095              36
# 9   2014    3                 37998               8
# 10  2015    3                 41299               9
# 11  2016    3                 36306             -12
# 12  2013    4                 35203              24
# 13  2014    4                 37381               6
# 14  2015    4                 39330               5
# 15  2016    4                 33569             -15

# %%
# extract violation count by police dist, year and qtr
def dist_Contrib_YOY():
    res = pd.DataFrame(session.query(V.SubAgency, V.Year, V.Qtr, func.sum(V.ViolationCount)).\
            group_by(V.SubAgency).group_by(V.Qtr).group_by(V.Year).all(), \
                       columns = ['SubAgency','Year', 'Qtr','Total_ViolationCount'])
    
    #   reshape result to calculate diff between Qtrs
    df_diff = pd.pivot_table(res, values = "Total_ViolationCount", index = ['SubAgency','Qtr'], columns = ['Year'])
    #calculate difference
    df_diff = df_diff.diff(axis = 1)
    
    # unstack to remove multilevel index
    d = df_diff.unstack().unstack().reset_index()
    
    #drop NAN and reset index
    d.dropna(how = "any", inplace = True)
    d.reset_index()
    
    # extract the data for total values
    df_tot = summarize_YR_QTR()
    
    # iterate to calculat the Contribution %
    df_result = []
    for index, row in d.iterrows():
        pct = (row[0]/(df_tot[(df_tot['Year'] == row.Year-1) & (df_tot.Qtr == row.Qtr)]['Total_ViolationCount'])).iloc[0]    
        df_result.append({
            'Year': row.Year,
            'Qtr':row.Qtr,
            'SubAgency':row.SubAgency,
            'Contrib_pct':pct
        })
        
        
    # merge data for violations by district/qtr/year with contribution pct
    df_final = pd.merge(res, pd.DataFrame(df_result), on = ['SubAgency','Qtr','Year'])
    
    # merge data for violations by district/qtr/year with contribution pct
    df_final = pd.merge(res, pd.DataFrame(df_result), on = ['SubAgency','Qtr','Year'])
    df_YOY = violation_YOY_Change()
    df_final1 = pd.merge(df_final, df_YOY, on = ['Qtr','Year'])
    
#     convert the YOY Change and countrib to % and round off

    df_final1.Contrib_pct = (df_final1.Contrib_pct * 100).apply(round, 2)
    return df_final1
    
    
dist_Contrib_YOY()
# Out:
#                                            SubAgency  Year  Qtr  \
# 0                            1st district, Rockville  2013    1
# 1                             2nd district, Bethesda  2013    1
# 2                        3rd district, Silver Spring  2013    1
# 3                              4th district, Wheaton  2013    1
# 4                           5th district, Germantown  2013    1
# 5    6th district, Gaithersburg / Montgomery Village  2013    1
# 6                Headquarters and Special Operations  2013    1
# 7                            1st district, Rockville  2014    1
# 8                             2nd district, Bethesda  2014    1
# 9                        3rd district, Silver Spring  2014    1
# 10                             4th district, Wheaton  2014    1
# 11                          5th district, Germantown  2014    1
# 12   6th district, Gaithersburg / Montgomery Village  2014    1
# 13               Headquarters and Special Operations  2014    1
# 14                           1st district, Rockville  2015    1
# 15                            2nd district, Bethesda  2015    1
# 16                       3rd district, Silver Spring  2015    1
# 17                             4th district, Wheaton  2015    1
# 18                          5th district, Germantown  2015    1
# 19   6th district, Gaithersburg / Montgomery Village  2015    1
# 20               Headquarters and Special Operations  2015    1
# 21                           1st district, Rockville  2016    1
# 22                            2nd district, Bethesda  2016    1
# 23                       3rd district, Silver Spring  2016    1
# 24                             4th district, Wheaton  2016    1
# 25                          5th district, Germantown  2016    1
# 26   6th district, Gaithersburg / Montgomery Village  2016    1
# 27               Headquarters and Special Operations  2016    1
# 28                           1st district, Rockville  2013    2
# 29                            2nd district, Bethesda  2013    2
# ..                                               ...   ...  ...
# 82   6th district, Gaithersburg / Montgomery Village  2016    3
# 83               Headquarters and Special Operations  2016    3
# 84                           1st district, Rockville  2013    4
# 85                            2nd district, Bethesda  2013    4
# 86                       3rd district, Silver Spring  2013    4
# 87                             4th district, Wheaton  2013    4
# 88                          5th district, Germantown  2013    4
# 89   6th district, Gaithersburg / Montgomery Village  2013    4
# 90               Headquarters and Special Operations  2013    4
# 91                           1st district, Rockville  2014    4
# 92                            2nd district, Bethesda  2014    4
# 93                       3rd district, Silver Spring  2014    4
# 94                             4th district, Wheaton  2014    4
# 95                          5th district, Germantown  2014    4
# 96   6th district, Gaithersburg / Montgomery Village  2014    4
# 97               Headquarters and Special Operations  2014    4
# 98                           1st district, Rockville  2015    4
# 99                            2nd district, Bethesda  2015    4
# 100                      3rd district, Silver Spring  2015    4
# 101                            4th district, Wheaton  2015    4
# 102                         5th district, Germantown  2015    4
# 103  6th district, Gaithersburg / Montgomery Village  2015    4
# 104              Headquarters and Special Operations  2015    4
# 105                          1st district, Rockville  2016    4
# 106                           2nd district, Bethesda  2016    4
# 107                      3rd district, Silver Spring  2016    4
# 108                            4th district, Wheaton  2016    4
# 109                         5th district, Germantown  2016    4
# 110  6th district, Gaithersburg / Montgomery Village  2016    4
# 111              Headquarters and Special Operations  2016    4
#
#      Total_ViolationCount_x  Contrib_pct  Total_ViolationCount_y  \
# 0                      4258            4                   29480
# 1                      4367           -1                   29480
# 2                      6783           12                   29480
# 3                      6177            6                   29480
# 4                      2781            1                   29480
# 5                      4453            3                   29480
# 6                       661            1                   29480
# 7                      4024           -1                   34673
# 8                      5223            3                   34673
# 9                      8554            6                   34673
# 10                     7406            4                   34673
# 11                     3922            4                   34673
# 12                     4121           -1                   34673
# 13                     1423            3                   34673
# 14                     3911            0                   36555
# 15                     5198            0                   36555
# 16                     7069           -4                   36555
# 17                     9382            6                   36555
# 18                     5152            4                   36555
# 19                     4597            1                   36555
# 20                     1246           -1                   36555
# 21                     4000            0                   39279
# 22                     5553            1                   39279
# 23                     8401            4                   39279
# 24                     9557            0                   39279
# 25                     4869           -1                   39279
# 26                     5338            2                   39279
# 27                     1561            1                   39279
# 28                     3498           -3                   32007
# 29                     4830            2                   32007
# ..                      ...          ...                     ...
# 82                     4475           -2                   36306
# 83                     2134            0                   36306
# 84                     3962            0                   35203
# 85                     4762            2                   35203
# 86                     8381            9                   35203
# 87                     7800            4                   35203
# 88                     3859            3                   35203
# 89                     4706            2                   35203
# 90                     1733            3                   35203
# 91                     4273            1                   37381
# 92                     5595            2                   37381
# 93                     7253           -3                   37381
# 94                     9667            5                   37381
# 95                     4579            2                   37381
# 96                     4445           -1                   37381
# 97                     1569            0                   37381
# 98                     3949           -1                   39330
# 99                     5581            0                   39330
# 100                    8253            3                   39330
# 101                    9038           -2                   39330
# 102                    5266            2                   39330
# 103                    5292            2                   39330
# 104                    1951            1                   39330
# 105                    3982            0                   33569
# 106                    4545           -3                   33569
# 107                    6360           -5                   33569
# 108                    9284            1                   33569
# 109                    3892           -3                   33569
# 110                    3979           -3                   33569
# 111                    1527           -1                   33569
#
#      YOY_Change_PCT
# 0                27
# 1                27
# 2                27
# 3                27
# 4                27
# 5                27
# 6                27
# 7                18
# 8                18
# 9                18
# 10               18
# 11               18
# 12               18
# 13               18
# 14                5
# 15                5
# 16                5
# 17                5
# 18                5
# 19                5
# 20                5
# 21                7
# 22                7
# 23                7
# 24                7
# 25                7
# 26                7
# 27                7
# 28               12
# 29               12
# ..              ...
# 82              -12
# 83              -12
# 84               24
# 85               24
# 86               24
# 87               24
# 88               24
# 89               24
# 90               24
# 91                6
# 92                6
# 93                6
# 94                6
# 95                6
# 96                6
# 97                6
# 98                5
# 99                5
# 100               5
# 101               5
# 102               5
# 103               5
# 104               5
# 105             -15
# 106             -15
# 107             -15
# 108             -15
# 109             -15
# 110             -15
# 111             -15
#
# [112 rows x 7 columns]

# %% [markdown]
# ### Data extraction for Dynamic charts

# %%
# function to extract Violation  by district
# parameters Year (All, specific Year), Category (All & specific category) and District (All and specific)
def filterData_main(yr = 0, cat = "all", dist = 0):
    
    _filter = [1==1, V.Qtr.in_([1,2,3,4])]
    
    if(yr != 0):
        _filter.append(V.Year.in_([yr]))
    
    if(cat != "all"):
        _filter.append(V.ViolationCategory.in_([cat]))
    
    if(dist != 0):
        _filter.append(V.PoliceDistrictID.in_([dist]))
    
    
    #list of items to select
    selList = [V.Year,V.Qtr,V.Month,V.SubAgency,V.PoliceDistrictID,V.ViolationType,V.ViolationCategory,
               V.VehicleGroup,V.PersonalInjury,V.PropertyDamage,V.Fatal,V.ContributedToAccident,V.ViolationCount]
    
    res = session.query(*selList).filter(*_filter).all()
                       
    df = pd.DataFrame(res, columns = ["Year","Qtr","Month","SubAgency","PoliceDistrictID","ViolationType",
                                      "ViolationCategory","VehicleGroup","PersonalInjury","PropertyDamage","Fatal",
                                      "ContributedToAccident","ViolationCount"])
    
    return df

# %%
filterData_main(2012, 'Distraction', 2)
# Out:
#     Year  Qtr  Month               SubAgency  PoliceDistrictID ViolationType  \
# 0   2012    1      1  2nd district, Bethesda                 2      Citation
# 1   2012    1      1  2nd district, Bethesda                 2      Citation
# 2   2012    1      1  2nd district, Bethesda                 2       Warning
# 3   2012    1      1  2nd district, Bethesda                 2       Warning
# 4   2012    1      2  2nd district, Bethesda                 2      Citation
# 5   2012    1      2  2nd district, Bethesda                 2      Citation
# 6   2012    1      2  2nd district, Bethesda                 2       Warning
# 7   2012    1      2  2nd district, Bethesda                 2       Warning
# 8   2012    1      3  2nd district, Bethesda                 2      Citation
# 9   2012    1      3  2nd district, Bethesda                 2      Citation
# 10  2012    1      3  2nd district, Bethesda                 2       Warning
# 11  2012    1      3  2nd district, Bethesda                 2       Warning
# 12  2012    2      4  2nd district, Bethesda                 2      Citation
# 13  2012    2      4  2nd district, Bethesda                 2       Warning
# 14  2012    2      5  2nd district, Bethesda                 2      Citation
# 15  2012    2      5  2nd district, Bethesda                 2      Citation
# 16  2012    2      5  2nd district, Bethesda                 2      Citation
# 17  2012    2      5  2nd district, Bethesda                 2       Warning
# 18  2012    2      5  2nd district, Bethesda                 2       Warning
# 19  2012    2      6  2nd district, Bethesda                 2      Citation
# 20  2012    2      6  2nd district, Bethesda                 2      Citation
# 21  2012    2      6  2nd district, Bethesda                 2       Warning
# 22  2012    3      7  2nd district, Bethesda                 2      Citation
# 23  2012    3      7  2nd district, Bethesda                 2      Citation
# 24  2012    3      7  2nd district, Bethesda                 2       Warning
# 25  2012    3      7  2nd district, Bethesda                 2       Warning
# 26  2012    3      8  2nd district, Bethesda                 2      Citation
# 27  2012    3      8  2nd district, Bethesda                 2      Citation
# 28  2012    3      8  2nd district, Bethesda                 2       Warning
# 29  2012    3      8  2nd district, Bethesda                 2       Warning
# 30  2012    3      8  2nd district, Bethesda                 2       Warning
# 31  2012    3      9  2nd district, Bethesda                 2      Citation
# 32  2012    3      9  2nd district, Bethesda                 2      Citation
# 33  2012    3      9  2nd district, Bethesda                 2      Citation
# 34  2012    3      9  2nd district, Bethesda                 2       Warning
# 35  2012    4     10  2nd district, Bethesda                 2      Citation
# 36  2012    4     10  2nd district, Bethesda                 2      Citation
# 37  2012    4     10  2nd district, Bethesda                 2       Warning
# 38  2012    4     10  2nd district, Bethesda                 2       Warning
# 39  2012    4     11  2nd district, Bethesda                 2      Citation
# 40  2012    4     11  2nd district, Bethesda                 2      Citation
# 41  2012    4     11  2nd district, Bethesda                 2       Warning
# 42  2012    4     11  2nd district, Bethesda                 2       Warning
# 43  2012    4     12  2nd district, Bethesda                 2      Citation
# 44  2012    4     12  2nd district, Bethesda                 2      Citation
# 45  2012    4     12  2nd district, Bethesda                 2       Warning
#
#    ViolationCategory VehicleGroup  PersonalInjury  PropertyDamage  Fatal  \
# 0        Distraction   Automobile             0.0             0.0    0.0
# 1        Distraction        Truck             0.0             0.0    0.0
# 2        Distraction   Automobile             0.0             0.0    0.0
# 3        Distraction        Truck             0.0             0.0    0.0
# 4        Distraction   Automobile             0.0             0.0    0.0
# 5        Distraction        Truck             0.0             0.0    0.0
# 6        Distraction   Automobile             0.0             0.0    0.0
# 7        Distraction        Truck             0.0             0.0    0.0
# 8        Distraction   Automobile             0.0             0.0    0.0
# 9        Distraction        Truck             0.0             0.0    0.0
# 10       Distraction   Automobile             0.0             0.0    0.0
# 11       Distraction        Truck             0.0             0.0    0.0
# 12       Distraction   Automobile             0.0             0.0    0.0
# 13       Distraction   Automobile             0.0             0.0    0.0
# 14       Distraction   Automobile             0.0             2.0    0.0
# 15       Distraction        Other             0.0             0.0    0.0
# 16       Distraction        Truck             0.0             0.0    0.0
# 17       Distraction   Automobile             0.0             0.0    0.0
# 18       Distraction        Truck             0.0             0.0    0.0
# 19       Distraction   Automobile             0.0             0.0    0.0
# 20       Distraction        Truck             0.0             0.0    0.0
# 21       Distraction   Automobile             0.0             0.0    0.0
# 22       Distraction   Automobile             0.0             0.0    0.0
# 23       Distraction        Truck             0.0             0.0    0.0
# 24       Distraction   Automobile             0.0             0.0    0.0
# 25       Distraction        Truck             0.0             0.0    0.0
# 26       Distraction   Automobile             0.0             0.0    0.0
# 27       Distraction        Other             0.0             0.0    0.0
# 28       Distraction   Automobile             0.0             0.0    0.0
# 29       Distraction        Other             0.0             0.0    0.0
# 30       Distraction        Truck             0.0             0.0    0.0
# 31       Distraction   Automobile             0.0             0.0    0.0
# 32       Distraction        Other             0.0             0.0    0.0
# 33       Distraction        Truck             0.0             0.0    0.0
# 34       Distraction   Automobile             0.0             0.0    0.0
# 35       Distraction   Automobile             0.0             0.0    0.0
# 36       Distraction        Truck             0.0             0.0    0.0
# 37       Distraction   Automobile             0.0             0.0    0.0
# 38       Distraction        Truck             0.0             0.0    0.0
# 39       Distraction   Automobile             0.0             0.0    0.0
# 40       Distraction        Truck             0.0             0.0    0.0
# 41       Distraction   Automobile             0.0             0.0    0.0
# 42       Distraction        Truck             0.0             0.0    0.0
# 43       Distraction   Automobile             0.0             0.0    0.0
# 44       Distraction        Truck             0.0             0.0    0.0
# 45       Distraction   Automobile             0.0             0.0    0.0
#
#     ContributedToAccident  ViolationCount
# 0                     0.0               6
# 1                     0.0               1
# 2                     0.0               4
# 3                     0.0               2
# 4                     0.0              13
# 5                     0.0               1
# 6                     0.0               5
# 7                     0.0               1
# 8                     0.0              11
# 9                     0.0               2
# 10                    0.0              11
# 11                    0.0               1
# 12                    0.0              10
# 13                    0.0               4
# 14                    1.0              14
# 15                    0.0               3
# 16                    0.0               3
# 17                    0.0              12
# 18                    0.0               6
# 19                    0.0               5
# 20                    0.0               1
# 21                    0.0               3
# 22                    0.0               8
# 23                    0.0               2
# 24                    0.0               4
# 25                    0.0               1
# 26                    0.0               6
# 27                    0.0               3
# 28                    0.0               4
# 29                    0.0               1
# 30                    0.0               1
# 31                    0.0               7
# 32                    0.0               2
# 33                    0.0               2
# 34                    0.0               5
# 35                    0.0               8
# 36                    0.0               1
# 37                    0.0               4
# 38                    0.0               2
# 39                    0.0               2
# 40                    0.0               1
# 41                    0.0               3
# 42                    0.0               1
# 43                    0.0               4
# 44                    0.0               1
# 45                    0.0               4

# %%
def getViolation_ByDist(yr, cat, dist):
    """ FUNCTION: getViolation_ByDist """
    """ desc : extract violation count by district and other filters as given by user (Year, Category and District) % """
    """ return DataFrame with SubAgency, Police District, Total Violations """
    
    df_all = filterData_main(yr, cat, dist)
    
    if(dist != 0):
        if(yr == 0):
            df_all = df_all[['Year','SubAgency','PoliceDistrictID','ViolationCount']].groupby(['Year','SubAgency','PoliceDistrictID'], as_index = False).agg(np.sum)
            df_all.columns = ['XValue','SubAgency','PoliceDistrictID','YValue']
        else:
            df_all = df_all[['Qtr','SubAgency','PoliceDistrictID','ViolationCount']].groupby(['Qtr','SubAgency','PoliceDistrictID'], as_index = False).agg(np.sum)
            df_all.columns = ['XValue','SubAgency','PoliceDistrictID','YValue']
    else:
        
        df_all = df_all[['SubAgency','PoliceDistrictID','ViolationCount']].groupby(['SubAgency','PoliceDistrictID'], as_index = False).agg(np.sum)
        df_all.columns = ['SubAgency','XValue','YValue']
    
#     df_all.reset_index(inplace = True)
    
    return df_all

getViolation_ByDist(0,"all",0)
# Out:
#                                          SubAgency  XValue  YValue
# 0                          1st district, Rockville       1   85385
# 1                           2nd district, Bethesda       2  101444
# 2                      3rd district, Silver Spring       3  143792
# 3                            4th district, Wheaton       4  160637
# 4                         5th district, Germantown       5   80363
# 5  6th district, Gaithersburg / Montgomery Village       6   96047
# 6              Headquarters and Special Operations       8   28750

# %%
def getViolation_ByCat(yr, cat, dist):
    """ FUNCTION: getViolation_ByCat """
    """ desc : extract violation count by Category and other filters as given by user (Year, Category and District) % """
    """ return DataFrame with ViolationCategory, Total Violations """
    
    df_all = filterData_main(yr, cat, dist)
    
    df_all = df_all[['ViolationCategory','ViolationCount']].\
                groupby(['ViolationCategory']).agg(np.sum)
    
    df_all.reset_index(inplace = True)
    
    return df_all

# getViolation_ByCat(0,"all",0)

# %%
def getViolation_ByType(yr, cat, dist):
    """ FUNCTION: getViolation_ByType """
    """ desc : extract violation count by Violation Type and other filters as given by user (Year, Category and District) % """
    """ return DataFrame with ViolationType, Total Violations """
    
    df_all = filterData_main(yr, cat, dist)
    
    df_all = df_all[['ViolationType','ViolationCount']].\
                groupby(['ViolationType']).agg(np.sum)
    
    df_all.reset_index(inplace = True)
    
    return df_all

getViolation_ByType(0,"all",0)
# Out:
#   ViolationType  ViolationCount
# 0      Citation          359997
# 1         ESERO           31120
# 2          SERO             832
# 3       Warning          304469

# %%
def getViolation_Impact(yr, cat, dist):
    """ FUNCTION: getViolation_Impact """
    """ desc : extract Impact of violation ie., PersonalInjury, PropDamage, Fatality and Accident"""
    """ return DataFrame with Impact of violation variables, Count of violation for  each variable and Total Violations """
    
    df_all = filterData_main(yr, cat, dist)
    
    V.Year,V.Qtr,V.Month,V.SubAgency,V.PoliceDistrictID,V.ViolationType,V.ViolationCategory,
               V.VehicleGroup,V.PersonalInjury,V.PropertyDamage,V.Fatal,V.ContributedToAccident,V.ViolationCount
        
    df_all = df_all[['PersonalInjury','PropDamage','ViolationCount']].\
                groupby(['ViolationType']).agg(np.sum)
    
    df_all.reset_index(inplace = True)
    
    return df_all

getViolation_ByType(0,"all",0)
# Out:
#   File "<ipython-input-23-a5a3a9271bfb>", line 9
#     V.VehicleGroup,V.PersonalInjury,V.PropertyDamage,V.Fatal,V.ContributedToAccident,V.ViolationCount
#     ^
# IndentationError: unexpected indent
